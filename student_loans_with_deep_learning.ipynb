# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student_loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/mbc/ai/m6/datasets/student_loans.csv"
df = pd.read_csv(file_path)

# Review the DataFrame
df.sample(7)
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 145               8.1                0.67               0.55          1.8
# 591               6.6                0.39               0.49          1.7
# 456               8.9                0.59               0.39          2.3
# 872               7.3                0.35               0.24          2.0
# 992               6.5                0.40               0.10          2.0
# 983               9.1                0.50               0.30          1.9
# 1141              8.2                0.38               0.32          2.5
#
#       alumni_success  study_major_code  time_to_completion  \
# 145            0.117              32.0               141.0
# 591            0.070              23.0               149.0
# 456            0.095               5.0                22.0
# 872            0.067              28.0                48.0
# 992            0.076              30.0                47.0
# 983            0.065               8.0                17.0
# 1141           0.080              24.0                71.0
#
#       finance_workshop_score  cohort_ranking  total_loan_score  \
# 145                  0.99680            3.17              0.62
# 591                  0.99220            3.12              0.50
# 456                  0.99860            3.37              0.58
# 872                  0.99576            3.43              0.54
# 992                  0.99554            3.36              0.48
# 983                  0.99774            3.32              0.71
# 1141                 0.99624            3.27              0.85
#
#       financial_aid_score  credit_ranking
# 145                   9.4               5
# 591                  11.5               6
# 456                  10.3               5
# 872                  10.0               4
# 992                   9.4               6
# 983                  10.5               6
# 1141                 11.0               6

# %%
# Review the data types associated with the columns
if df.isna().values.any():
  print('There are missing values in the dataset.')
else:
  print('There are no missing (null) values.')
duplicated_rows = df[df.duplicated()]
if len(duplicated_rows) > 0:
  print(f'There are {len(duplicated_rows)} duplicated rows in the dataset.')
print('All values are numerical.')
df.info()
# Out:
# There are no missing (null) values.
# There are 240 duplicated rows in the dataset.
# All values are numerical.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   payment_history         1599 non-null   float64
#  1   location_parameter      1599 non-null   float64
#  2   stem_degree_score       1599 non-null   float64
#  3   gpa_ranking             1599 non-null   float64
#  4   alumni_success          1599 non-null   float64
#  5   study_major_code        1599 non-null   float64
#  6   time_to_completion      1599 non-null   float64
#  7   finance_workshop_score  1599 non-null   float64
#  8   cohort_ranking          1599 non-null   float64
#  9   total_loan_score        1599 non-null   float64
#  10  financial_aid_score     1599 non-null   float64
#  11  credit_ranking          1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# #### Inspect the features' values and target distribution

# %%
print(f"Balance of target variables?\n\n{df['credit_ranking'].value_counts()}.\n")
print('Statistical spread of values in columns:')
df.describe()
# Out:
# Balance of target variables?
#
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: credit_ranking, dtype: int64.
#
# Statistical spread of values in columns:
#        payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# count      1599.000000         1599.000000        1599.000000  1599.000000
# mean          8.319637            0.527821           0.270976     2.538806
# std           1.741096            0.179060           0.194801     1.409928
# min           4.600000            0.120000           0.000000     0.900000
# 25%           7.100000            0.390000           0.090000     1.900000
# 50%           7.900000            0.520000           0.260000     2.200000
# 75%           9.200000            0.640000           0.420000     2.600000
# max          15.900000            1.580000           1.000000    15.500000
#
#        alumni_success  study_major_code  time_to_completion  \
# count     1599.000000       1599.000000         1599.000000
# mean         0.087467         15.874922           46.467792
# std          0.047065         10.460157           32.895324
# min          0.012000          1.000000            6.000000
# 25%          0.070000          7.000000           22.000000
# 50%          0.079000         14.000000           38.000000
# 75%          0.090000         21.000000           62.000000
# max          0.611000         72.000000          289.000000
#
#        finance_workshop_score  cohort_ranking  total_loan_score  \
# count             1599.000000     1599.000000       1599.000000
# mean                 0.996747        3.311113          0.658149
# std                  0.001887        0.154386          0.169507
# min                  0.990070        2.740000          0.330000
# 25%                  0.995600        3.210000          0.550000
# 50%                  0.996750        3.310000          0.620000
# 75%                  0.997835        3.400000          0.730000
# max                  1.003690        4.010000          2.000000
#
#        financial_aid_score  credit_ranking
# count          1599.000000     1599.000000
# mean             10.422983        5.636023
# std               1.065668        0.807569
# min               8.400000        3.000000
# 25%               9.500000        5.000000
# 50%              10.200000        6.000000
# 75%              11.100000        6.000000
# max              14.900000        8.000000

# %% [markdown]
# * There is an imbalanced distribution of credit_ranking (target) values.
# May need to consider a rebalance.

# %% [markdown]
# ####Testing credit significance of a subset of data
# check stem_degree_score == 0 (since it is the only column with 0 values in it ie. min=0)

# %%
df['credit_ranking'].loc[df['stem_degree_score'] == 0].value_counts()
# Out:
# 5    57
# 6    54
# 4    10
# 7     8
# 3     3
# Name: credit_ranking, dtype: int64

# %% [markdown]
# Appears to be distributed in line with broader dataset.

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
# y = df['credit_ranking'].ravel()
y = df['credit_ranking'].ravel()
# Display a sample of y
y[:5]
# Out:
# array([5, 5, 5, 6, 5])

# %%
# Define features set X by selecting all columns but credit_ranking
X = df.drop(columns='credit_ranking')

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)

# Scale the features training and testing datasets
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Additional Step: Since target data contains less lower credit ratings, generate a re-sampled set of training data.

# %%
# Import SMOTE from imblearn
from imblearn.over_sampling import SMOTE

# Instantiate the SMOTE instance
# Set the sampling_strategy parameter equal to auto
smote_sampler = SMOTE(random_state=1, sampling_strategy='auto')

# Fit the training data to the smote_sampler model
X_resampled, y_resampled = smote_sampler.fit_resample(X_train_scaled, y_train)

# Compare distinct value counts for the original and resampled target training data
print(f'Original Value counts:\n{pd.DataFrame(y_train).value_counts()}')
print(f'Resampled value counts:\n{pd.DataFrame(y_resampled).value_counts()}')
# Out:
# Original Value counts:
# 5    510
# 6    471
# 7    157
# 4     37
# 8     15
# 3      9
# dtype: int64
# Resampled value counts:
# 3    510
# 4    510
# 5    510
# 6    510
# 7    510
# 8    510
# dtype: int64

# %% [markdown]
# ---
#
# ## First extablish baseline accuracy model with hyperparemter tuned RandomForest/s
# a) RandomForest
#
# b) XGBoost

# %%
# import the additional libraries
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
rf_regressor = RandomForestRegressor(random_state=1)
# set up rf search grid
rf_param_grid = {"max_depth": np.arange(1,7,1),
              "n_estimators": np.arange(60,200,20)}

# try out every combination of the above values
rf_search = GridSearchCV(rf_regressor, rf_param_grid, cv=5).fit(X_train_scaled, y_train)
# rf_search = GridSearchCV(rf_regressor, rf_param_grid, cv=5).fit(X_resampled, y_resampled)
# rf_search = RandomizedSearchCV(rf_regressor, rf_param_grid, cv=5).fit(X_train_scaled, y_train)
# rf_search = RandomizedSearchCV(rf_regressor, rf_param_grid, cv=5).fit(X_resampled, y_resampled)
print("The best hyperparameters are ", rf_search.best_params_)
# Out:
# The best hyperparameters are  {'max_depth': 6, 'n_estimators': 180}

# %%
# apply best parameters
tuned_rf_regressor = RandomForestRegressor(
    n_estimators=rf_search.best_params_["n_estimators"],
    max_depth=rf_search.best_params_["max_depth"],
    random_state=1)
# fit (train) the model
tuned_rf_regressor.fit(X_train_scaled, y_train)
# evaluate
y_pred_rf = tuned_rf_regressor.predict(X_test_scaled).round().astype("int32").ravel()

rf_accuracy = accuracy_score(y_test, y_pred_rf)
print(f'Random Forest Regressor model accuracy score: {rf_accuracy * 100:.3f}%')
# Out:
# Random Forest Regressor model accuracy score: 62.250%

# %%
xg_regressor=xgb.XGBRegressor(random_state=1)
# set up xg search grid
xg_param_grid = {"max_depth": np.arange(1,7,1),
              "n_estimators": np.arange(60,200,20),
              "learning_rate": np.arange(0.01, 0.95, 0.05)}

# try out every combination of the above values
xg_search = GridSearchCV(xg_regressor, xg_param_grid, cv=5).fit(X_train_scaled, y_train)
# xg_search = GridSearchCV(xg_regressor, xg_param_grid, cv=5).fit(X_resampled, y_resampled)
# xg_search = RandomizedSearchCV(xg_regressor, xg_param_grid, cv=5).fit(X_train_scaled, y_train)
# xg_search = RandomizedSearchCV(xg_regressor, xg_param_grid, cv=5).fit(X_resampled, y_resampled)
print("The best hyperparameters are ", xg_search.best_params_)
# Out:
# The best hyperparameters are  {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 100}

# %%
# Make predictions and evaluate based on seatrch outcome
xg_srch_pred = xg_search.predict(X_test_scaled).round().astype("int32").ravel()
xg_srch_acc = accuracy_score(y_test, xg_srch_pred)
print(f'XG Boost model accuracy score: {xg_srch_acc * 100:.3f}%')
# Out:
# XG Boost model accuracy score: 68.750%

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
num_inputs = 11
print(f'Num Inputs: {num_inputs}')
# Review the number of features
print(f'Num features: {X.shape[1]}')
# Out:
# Num Inputs: 11
# Num features: 11

# %%
# Define the number of neurons in the output layer
output_neurons = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes = []
hidden_nodes.append(6)
# Review the number hidden nodes in the first layer
print(f'Hidden nodes in the first layer: {hidden_nodes[0]}')
# Out:
# Hidden nodes in the first layer: 6

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes.append(3)
# Review the number hidden nodes in the second layer
print(f'Hidden nodes in the second layer: {hidden_nodes[1]}')
# Out:
# Hidden nodes in the second layer: 3

# %%
# Create the Sequential model instance
nn = Sequential()

# %%
# Add the first hidden layer
nn.add(Dense(input_dim=num_inputs,
             units=hidden_nodes[0],
             activation='relu'))

# %%
# Add the second hidden layer
nn.add(Dense(units=hidden_nodes[1],
             activation='relu'))

# %%
# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(Dense(units=output_neurons,
             activation='linear'))

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 3)                 21
#
#  dense_2 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `mse` loss function, the `adam` optimizer, and the `mse` evaluation metric.

# %%
# Compile the Sequential model
nn.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])

# %%
# Fit the model using 50 epochs and the training data
seq_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 32.5994 - mse: 32.5994
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 31.4780 - mse: 31.4780
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 30.2859 - mse: 30.2859
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 28.6720 - mse: 28.6720
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 26.3419 - mse: 26.3419
# Epoch 6/50
# 38/38 [==============================] - 0s 3ms/step - loss: 23.3474 - mse: 23.3474
# Epoch 7/50
# 38/38 [==============================] - 0s 3ms/step - loss: 19.9545 - mse: 19.9545
# Epoch 8/50
# 38/38 [==============================] - 0s 3ms/step - loss: 16.4966 - mse: 16.4966
# Epoch 9/50
# 38/38 [==============================] - 0s 3ms/step - loss: 13.2473 - mse: 13.2473
# Epoch 10/50
# 38/38 [==============================] - 0s 3ms/step - loss: 10.4318 - mse: 10.4318
# Epoch 11/50
# 38/38 [==============================] - 0s 3ms/step - loss: 8.2094 - mse: 8.2094
# Epoch 12/50
# 38/38 [==============================] - 0s 3ms/step - loss: 6.6018 - mse: 6.6018
# Epoch 13/50
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4806 - mse: 5.4806
# Epoch 14/50
# 38/38 [==============================] - 0s 3ms/step - loss: 4.6811 - mse: 4.6811
# Epoch 15/50
# 38/38 [==============================] - 0s 3ms/step - loss: 4.1034 - mse: 4.1034
# Epoch 16/50
# 38/38 [==============================] - 0s 3ms/step - loss: 3.6665 - mse: 3.6665
# Epoch 17/50
# 38/38 [==============================] - 0s 3ms/step - loss: 3.3315 - mse: 3.3315
# Epoch 18/50
# 38/38 [==============================] - 0s 3ms/step - loss: 3.0528 - mse: 3.0528
# Epoch 19/50
# 38/38 [==============================] - 0s 3ms/step - loss: 2.8164 - mse: 2.8164
# Epoch 20/50
# 38/38 [==============================] - 0s 3ms/step - loss: 2.6148 - mse: 2.6148
# Epoch 21/50
# 38/38 [==============================] - 0s 3ms/step - loss: 2.4488 - mse: 2.4488
# Epoch 22/50
# 38/38 [==============================] - 0s 3ms/step - loss: 2.2989 - mse: 2.2989
# Epoch 23/50
# 38/38 [==============================] - 0s 3ms/step - loss: 2.1672 - mse: 2.1672
# Epoch 24/50
# 38/38 [==============================] - 0s 3ms/step - loss: 2.0455 - mse: 2.0455
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9405 - mse: 1.9405
# Epoch 26/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.8474 - mse: 1.8474
# Epoch 27/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.7596 - mse: 1.7596
# Epoch 28/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.6850 - mse: 1.6850
# Epoch 29/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.6108 - mse: 1.6108
# Epoch 30/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.5462 - mse: 1.5462
# Epoch 31/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4837 - mse: 1.4837
# Epoch 32/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.4244 - mse: 1.4244
# Epoch 33/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.3700 - mse: 1.3700
# Epoch 34/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.3186 - mse: 1.3186
# Epoch 35/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2693 - mse: 1.2693
# Epoch 36/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2226 - mse: 1.2226
# Epoch 37/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.1757 - mse: 1.1757
# Epoch 38/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.1322 - mse: 1.1322
# Epoch 39/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0884 - mse: 1.0884
# Epoch 40/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0471 - mse: 1.0471
# Epoch 41/50
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0088 - mse: 1.0088
# Epoch 42/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9742 - mse: 0.9742
# Epoch 43/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9428 - mse: 0.9428
# Epoch 44/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9152 - mse: 0.9152
# Epoch 45/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8844 - mse: 0.8844
# Epoch 46/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8566 - mse: 0.8566
# Epoch 47/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8313 - mse: 0.8313
# Epoch 48/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8082 - mse: 0.8082
# Epoch 49/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7864 - mse: 0.7864
# Epoch 50/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7635 - mse: 0.7635

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
seq_model_loss, seq_model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {seq_model_loss}, Accuracy: {seq_model_accuracy * 100:.3f}%")
# Out:
# 13/13 - 0s - loss: 0.8079 - mse: 0.8079 - 169ms/epoch - 13ms/step
# Loss: 0.8079410791397095, Accuracy: 80.794%

# %% [markdown]
# Similar to RandomForest baseline. Save but definitely worth seeking a better accuracy for the required purpose.

# %%
# Set and save the model's file path - allowing for multiple notebook runs
path = f"saved_models/student_loans.h5"
file_path = Path(path)
file_paths = []
file_paths.append(path.split('/')[1:2][0])

# Export your model to an HDF5 file
nn.save(file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ####Apply the following additional steps:
#
# 1) apply SMOTE resampled training data to the Sequential model and evaluate
#
# 2) add additional hidden layers and try with both non-sampled and SMOTE resampled training data

# %%
# Create a separate instance for training with sampled data
nn_smote = Sequential()
nn_smote.add(Dense(input_dim=num_inputs,
                   units=hidden_nodes[0],
                   activation='relu'))
nn_smote.add(Dense(units=hidden_nodes[1],
                   activation='relu'))
nn_smote.add(Dense(units=output_neurons,
                   activation='linear'))
nn_smote.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 6)                 72
#
#  dense_4 (Dense)             (None, 3)                 21
#
#  dense_5 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_smote.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])

# %%
# Fit using 100 epochs and the SMOTE sampled training data
smote_seq_model = nn_smote.fit(X_resampled, y_resampled, epochs=100)
# Out:
# Epoch 1/100
# 96/96 [==============================] - 1s 2ms/step - loss: 37.0083 - mse: 37.0083
# Epoch 2/100
# 96/96 [==============================] - 0s 2ms/step - loss: 30.9217 - mse: 30.9217
# Epoch 3/100
# 96/96 [==============================] - 0s 2ms/step - loss: 25.1081 - mse: 25.1081
# Epoch 4/100
# 96/96 [==============================] - 0s 2ms/step - loss: 17.0142 - mse: 17.0142
# Epoch 5/100
# 96/96 [==============================] - 0s 2ms/step - loss: 8.4187 - mse: 8.4187
# Epoch 6/100
# 96/96 [==============================] - 0s 2ms/step - loss: 3.7745 - mse: 3.7745
# Epoch 7/100
# 96/96 [==============================] - 0s 2ms/step - loss: 2.5608 - mse: 2.5608
# Epoch 8/100
# 96/96 [==============================] - 0s 2ms/step - loss: 2.1294 - mse: 2.1294
# Epoch 9/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.8452 - mse: 1.8452
# Epoch 10/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.6639 - mse: 1.6639
# Epoch 11/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.5301 - mse: 1.5301
# Epoch 12/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.4252 - mse: 1.4252
# Epoch 13/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.3360 - mse: 1.3360
# Epoch 14/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.2604 - mse: 1.2604
# Epoch 15/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.1946 - mse: 1.1946
# Epoch 16/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.1355 - mse: 1.1355
# Epoch 17/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.0839 - mse: 1.0839
# Epoch 18/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.0371 - mse: 1.0371
# Epoch 19/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.9998 - mse: 0.9998
# Epoch 20/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.9620 - mse: 0.9620
# Epoch 21/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.9307 - mse: 0.9307
# Epoch 22/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.9018 - mse: 0.9018
# Epoch 23/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.8760 - mse: 0.8760
# Epoch 24/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.8508 - mse: 0.8508
# Epoch 25/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.8279 - mse: 0.8279
# Epoch 26/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.8080 - mse: 0.8080
# Epoch 27/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.7882 - mse: 0.7882
# Epoch 28/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.7699 - mse: 0.7699
# Epoch 29/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.7540 - mse: 0.7540
# Epoch 30/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.7418 - mse: 0.7418
# Epoch 31/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.7268 - mse: 0.7268
# Epoch 32/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.7149 - mse: 0.7149
# Epoch 33/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.7049 - mse: 0.7049
# Epoch 34/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6963 - mse: 0.6963
# Epoch 35/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6888 - mse: 0.6888
# Epoch 36/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6819 - mse: 0.6819
# Epoch 37/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6762 - mse: 0.6762
# Epoch 38/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6700 - mse: 0.6700
# Epoch 39/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6663 - mse: 0.6663
# Epoch 40/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6619 - mse: 0.6619
# Epoch 41/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6554 - mse: 0.6554
# Epoch 42/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6533 - mse: 0.6533
# Epoch 43/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6486 - mse: 0.6486
# Epoch 44/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6444 - mse: 0.6444
# Epoch 45/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6408 - mse: 0.6408
# Epoch 46/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6409 - mse: 0.6409
# Epoch 47/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6338 - mse: 0.6338
# Epoch 48/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6322 - mse: 0.6322
# Epoch 49/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6277 - mse: 0.6277
# Epoch 50/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6245 - mse: 0.6245
# Epoch 51/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6234 - mse: 0.6234
# Epoch 52/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6178 - mse: 0.6178
# Epoch 53/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6170 - mse: 0.6170
# Epoch 54/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6148 - mse: 0.6148
# Epoch 55/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6102 - mse: 0.6102
# Epoch 56/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6049 - mse: 0.6049
# Epoch 57/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6013 - mse: 0.6013
# Epoch 58/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5965 - mse: 0.5965
# Epoch 59/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5950 - mse: 0.5950
# Epoch 60/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5892 - mse: 0.5892
# Epoch 61/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5874 - mse: 0.5874
# Epoch 62/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5841 - mse: 0.5841
# Epoch 63/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5824 - mse: 0.5824
# Epoch 64/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5799 - mse: 0.5799
# Epoch 65/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5774 - mse: 0.5774
# Epoch 66/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5749 - mse: 0.5749
# Epoch 67/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5719 - mse: 0.5719
# Epoch 68/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5701 - mse: 0.5701
# Epoch 69/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5665 - mse: 0.5665
# Epoch 70/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5638 - mse: 0.5638
# Epoch 71/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5645 - mse: 0.5645
# Epoch 72/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5599 - mse: 0.5599
# Epoch 73/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5578 - mse: 0.5578
# Epoch 74/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5549 - mse: 0.5549
# Epoch 75/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5514 - mse: 0.5514
# Epoch 76/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5514 - mse: 0.5514
# Epoch 77/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5470 - mse: 0.5470
# Epoch 78/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5442 - mse: 0.5442
# Epoch 79/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5433 - mse: 0.5433
# Epoch 80/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5397 - mse: 0.5397
# Epoch 81/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5391 - mse: 0.5391
# Epoch 82/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5362 - mse: 0.5362
# Epoch 83/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5386 - mse: 0.5386
# Epoch 84/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5341 - mse: 0.5341
# Epoch 85/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5341 - mse: 0.5341
# Epoch 86/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5333 - mse: 0.5333
# Epoch 87/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5313 - mse: 0.5313
# Epoch 88/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5285 - mse: 0.5285
# Epoch 89/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5283 - mse: 0.5283
# Epoch 90/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5281 - mse: 0.5281
# Epoch 91/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5269 - mse: 0.5269
# Epoch 92/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5227 - mse: 0.5227
# Epoch 93/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5223 - mse: 0.5223
# Epoch 94/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5206 - mse: 0.5206
# Epoch 95/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5205 - mse: 0.5205
# Epoch 96/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5183 - mse: 0.5183
# Epoch 97/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5167 - mse: 0.5167
# Epoch 98/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5172 - mse: 0.5172
# Epoch 99/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5162 - mse: 0.5162
# Epoch 100/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5153 - mse: 0.5153

# %%
# Evaluate the SMOTE model loss and accuracy metrics using the evaluate method and the test data
smote_model_loss, smote_model_accuracy = nn_smote.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {smote_model_loss}, Accuracy: {smote_model_accuracy * 100:.3f}%")
# Out:
# 13/13 - 0s - loss: 0.9130 - mse: 0.9130 - 142ms/epoch - 11ms/step
# Loss: 0.9129549264907837, Accuracy: 91.295%

# %% [markdown]
# Better result - save again and now try re-structuring the model

# %%
# Set and save the model's file path - allowing for training run instance
path = f"saved_models/student_loans_smote_new.h5"
file_path = Path(path)
file_paths.append(path.split('/')[1:2][0])

# Export your model to an HDF5 file
nn_smote.save(file_path)

# %% [markdown]
# ## 2) Additional Hidden Layers

# %%
hidden_nodes = [9, 7, 5, 3]
# redefine new nn model with additional layers
nn_2 = Sequential()

# Add the first hidden layer
nn_2.add(Dense(input_dim=num_inputs,
               units=hidden_nodes[0],
               activation='relu'))

for layer in range(1, len(hidden_nodes)):
  # Add the other hidden layer/s
  nn_2.add(Dense(units=hidden_nodes[layer],
                 activation='relu'))

# add output layer
nn_2.add(Dense(units=output_neurons,
               activation='linear'))

# print the summary configuration
nn_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 9)                 108
#
#  dense_7 (Dense)             (None, 7)                 70
#
#  dense_8 (Dense)             (None, 5)                 40
#
#  dense_9 (Dense)             (None, 3)                 18
#
#  dense_10 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 240 (960.00 Byte)
# Trainable params: 240 (960.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the new model
nn_2.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])

# Fit the new model using 100 epochs and the training data
seq_model_2 = nn_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 2ms/step - loss: 31.0804 - mse: 31.0804
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 28.0984 - mse: 28.0984
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 22.7229 - mse: 22.7229
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 13.9564 - mse: 13.9564
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6.1855 - mse: 6.1855
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.9844 - mse: 3.9844
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3518 - mse: 3.3518
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.9158 - mse: 2.9158
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.5497 - mse: 2.5497
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2625 - mse: 2.2625
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0320 - mse: 2.0320
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8384 - mse: 1.8384
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6734 - mse: 1.6734
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5370 - mse: 1.5370
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4342 - mse: 1.4342
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3418 - mse: 1.3418
# Epoch 17/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2626 - mse: 1.2626
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1936 - mse: 1.1936
# Epoch 19/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.1311 - mse: 1.1311
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0756 - mse: 1.0756
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0261 - mse: 1.0261
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9779 - mse: 0.9779
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9384 - mse: 0.9384
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8983 - mse: 0.8983
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8645 - mse: 0.8645
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8320 - mse: 0.8320
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8041 - mse: 0.8041
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7748 - mse: 0.7748
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7502 - mse: 0.7502
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7294 - mse: 0.7294
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7064 - mse: 0.7064
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6896 - mse: 0.6896
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6708 - mse: 0.6708
# Epoch 34/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6508 - mse: 0.6508
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6332 - mse: 0.6332
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6219 - mse: 0.6219
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6084 - mse: 0.6084
# Epoch 38/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5937 - mse: 0.5937
# Epoch 39/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5826 - mse: 0.5826
# Epoch 40/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5712 - mse: 0.5712
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5581 - mse: 0.5581
# Epoch 42/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5470 - mse: 0.5470
# Epoch 43/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5368 - mse: 0.5368
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5304 - mse: 0.5304
# Epoch 45/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5208 - mse: 0.5208
# Epoch 46/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5136 - mse: 0.5136
# Epoch 47/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5073 - mse: 0.5073
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5026 - mse: 0.5026
# Epoch 49/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4990 - mse: 0.4990
# Epoch 50/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4898 - mse: 0.4898
# Epoch 51/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4805 - mse: 0.4805
# Epoch 52/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4731 - mse: 0.4731
# Epoch 53/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4691 - mse: 0.4691
# Epoch 54/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4636 - mse: 0.4636
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4589 - mse: 0.4589
# Epoch 56/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4528 - mse: 0.4528
# Epoch 57/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4509 - mse: 0.4509
# Epoch 58/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4444 - mse: 0.4444
# Epoch 59/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4425 - mse: 0.4425
# Epoch 60/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4345 - mse: 0.4345
# Epoch 61/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4300 - mse: 0.4300
# Epoch 62/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4270 - mse: 0.4270
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4206 - mse: 0.4206
# Epoch 64/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4203 - mse: 0.4203
# Epoch 65/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4179 - mse: 0.4179
# Epoch 66/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4154 - mse: 0.4154
# Epoch 67/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4105 - mse: 0.4105
# Epoch 68/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4089 - mse: 0.4089
# Epoch 69/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4050 - mse: 0.4050
# Epoch 70/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4025 - mse: 0.4025
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4032 - mse: 0.4032
# Epoch 72/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4007 - mse: 0.4007
# Epoch 73/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4047 - mse: 0.4047
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3955 - mse: 0.3955
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3931 - mse: 0.3931
# Epoch 76/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3938 - mse: 0.3938
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3918 - mse: 0.3918
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3918 - mse: 0.3918
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3894 - mse: 0.3894
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3873 - mse: 0.3873
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3864 - mse: 0.3864
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3851 - mse: 0.3851
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3836 - mse: 0.3836
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3839 - mse: 0.3839
# Epoch 85/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3796 - mse: 0.3796
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3824 - mse: 0.3824
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3796 - mse: 0.3796
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3793 - mse: 0.3793
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3794 - mse: 0.3794
# Epoch 90/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3782 - mse: 0.3782
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3796 - mse: 0.3796
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3777 - mse: 0.3777
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3814 - mse: 0.3814
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3793 - mse: 0.3793
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3752 - mse: 0.3752
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3758 - mse: 0.3758
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3735 - mse: 0.3735
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3754 - mse: 0.3754
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3744 - mse: 0.3744
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3706 - mse: 0.3706

# %%
# Evaluate the new model loss and accuracy metrics
seq_model_2_loss, seq_model_2_accuracy = nn_2.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {seq_model_2_loss}, Accuracy: {seq_model_2_accuracy * 100:.3f}%")
# Out:
# 13/13 - 0s - loss: 0.4223 - mse: 0.4223 - 145ms/epoch - 11ms/step
# Loss: 0.42234283685684204, Accuracy: 42.234%

# %%
# Set and save the model's file path - allowing for training run instance
path = f"saved_models/student_loans_2.h5"
file_path = Path(path)
file_paths.append(path.split('/')[1:2][0])

# Export your model to an HDF5 file
nn_2.save(file_path)

# %%
# Create another instance of the new model for training with sampled data
nn_2_smote = Sequential()

# Add the first hidden layer
nn_2_smote.add(Dense(input_dim=num_inputs,
                     units=hidden_nodes[0],
                     activation='relu'))

for layer in range(1, len(hidden_nodes)):
  # Add the other hidden layer/s
  nn_2_smote.add(Dense(units=hidden_nodes[layer],
                       activation='relu'))

# add output layer
nn_2_smote.add(Dense(units=output_neurons,
                     activation='linear'))

# print the summary configuration
nn_2_smote.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 9)                 108
#
#  dense_12 (Dense)            (None, 7)                 70
#
#  dense_13 (Dense)            (None, 5)                 40
#
#  dense_14 (Dense)            (None, 3)                 18
#
#  dense_15 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 240 (960.00 Byte)
# Trainable params: 240 (960.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the new model
nn_2_smote.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])

# Fit the new model using 100 epochs and the SMOTE sampled training data
smote_seq_model_2 = nn_2_smote.fit(X_resampled, y_resampled, epochs=100)
# Out:
# Epoch 1/100
# 96/96 [==============================] - 1s 2ms/step - loss: 30.7427 - mse: 30.7427
# Epoch 2/100
# 96/96 [==============================] - 0s 2ms/step - loss: 11.3055 - mse: 11.3055
# Epoch 3/100
# 96/96 [==============================] - 0s 2ms/step - loss: 2.8467 - mse: 2.8467
# Epoch 4/100
# 96/96 [==============================] - 0s 2ms/step - loss: 2.1266 - mse: 2.1266
# Epoch 5/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.7046 - mse: 1.7046
# Epoch 6/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.4537 - mse: 1.4537
# Epoch 7/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.2829 - mse: 1.2829
# Epoch 8/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.1562 - mse: 1.1562
# Epoch 9/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.0619 - mse: 1.0619
# Epoch 10/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.9906 - mse: 0.9906
# Epoch 11/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.9313 - mse: 0.9313
# Epoch 12/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.8883 - mse: 0.8883
# Epoch 13/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.8494 - mse: 0.8494
# Epoch 14/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.8143 - mse: 0.8143
# Epoch 15/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.7912 - mse: 0.7912
# Epoch 16/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.7635 - mse: 0.7635
# Epoch 17/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.7431 - mse: 0.7431
# Epoch 18/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.7271 - mse: 0.7271
# Epoch 19/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.7097 - mse: 0.7097
# Epoch 20/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6950 - mse: 0.6950
# Epoch 21/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6820 - mse: 0.6820
# Epoch 22/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6692 - mse: 0.6692
# Epoch 23/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6647 - mse: 0.6647
# Epoch 24/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6540 - mse: 0.6540
# Epoch 25/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6442 - mse: 0.6442
# Epoch 26/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6366 - mse: 0.6366
# Epoch 27/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6310 - mse: 0.6310
# Epoch 28/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6245 - mse: 0.6245
# Epoch 29/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6192 - mse: 0.6192
# Epoch 30/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6135 - mse: 0.6135
# Epoch 31/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6081 - mse: 0.6081
# Epoch 32/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6002 - mse: 0.6002
# Epoch 33/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5975 - mse: 0.5975
# Epoch 34/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5921 - mse: 0.5921
# Epoch 35/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5904 - mse: 0.5904
# Epoch 36/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5856 - mse: 0.5856
# Epoch 37/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5812 - mse: 0.5812
# Epoch 38/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5790 - mse: 0.5790
# Epoch 39/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5706 - mse: 0.5706
# Epoch 40/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5675 - mse: 0.5675
# Epoch 41/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5632 - mse: 0.5632
# Epoch 42/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5639 - mse: 0.5639
# Epoch 43/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5584 - mse: 0.5584
# Epoch 44/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5540 - mse: 0.5540
# Epoch 45/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5497 - mse: 0.5497
# Epoch 46/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5456 - mse: 0.5456
# Epoch 47/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5442 - mse: 0.5442
# Epoch 48/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5403 - mse: 0.5403
# Epoch 49/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5392 - mse: 0.5392
# Epoch 50/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5354 - mse: 0.5354
# Epoch 51/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5346 - mse: 0.5346
# Epoch 52/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5299 - mse: 0.5299
# Epoch 53/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5271 - mse: 0.5271
# Epoch 54/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5292 - mse: 0.5292
# Epoch 55/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5237 - mse: 0.5237
# Epoch 56/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5222 - mse: 0.5222
# Epoch 57/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5212 - mse: 0.5212
# Epoch 58/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5191 - mse: 0.5191
# Epoch 59/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5189 - mse: 0.5189
# Epoch 60/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.5157 - mse: 0.5157
# Epoch 61/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5139 - mse: 0.5139
# Epoch 62/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5110 - mse: 0.5110
# Epoch 63/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5141 - mse: 0.5141
# Epoch 64/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5129 - mse: 0.5129
# Epoch 65/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5099 - mse: 0.5099
# Epoch 66/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5078 - mse: 0.5078
# Epoch 67/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5087 - mse: 0.5087
# Epoch 68/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5057 - mse: 0.5057
# Epoch 69/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5023 - mse: 0.5023
# Epoch 70/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5020 - mse: 0.5020
# Epoch 71/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4975 - mse: 0.4975
# Epoch 72/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4975 - mse: 0.4975
# Epoch 73/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4979 - mse: 0.4979
# Epoch 74/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5012 - mse: 0.5012
# Epoch 75/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4939 - mse: 0.4939
# Epoch 76/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4913 - mse: 0.4913
# Epoch 77/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4914 - mse: 0.4914
# Epoch 78/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4905 - mse: 0.4905
# Epoch 79/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4892 - mse: 0.4892
# Epoch 80/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4878 - mse: 0.4878
# Epoch 81/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4866 - mse: 0.4866
# Epoch 82/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4844 - mse: 0.4844
# Epoch 83/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4852 - mse: 0.4852
# Epoch 84/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4824 - mse: 0.4824
# Epoch 85/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4807 - mse: 0.4807
# Epoch 86/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4804 - mse: 0.4804
# Epoch 87/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4811 - mse: 0.4811
# Epoch 88/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4781 - mse: 0.4781
# Epoch 89/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4806 - mse: 0.4806
# Epoch 90/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4796 - mse: 0.4796
# Epoch 91/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4777 - mse: 0.4777
# Epoch 92/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4754 - mse: 0.4754
# Epoch 93/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4763 - mse: 0.4763
# Epoch 94/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4749 - mse: 0.4749
# Epoch 95/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4726 - mse: 0.4726
# Epoch 96/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4705 - mse: 0.4705
# Epoch 97/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4693 - mse: 0.4693
# Epoch 98/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4674 - mse: 0.4674
# Epoch 99/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.4664 - mse: 0.4664
# Epoch 100/100
# 96/96 [==============================] - 0s 4ms/step - loss: 0.4634 - mse: 0.4634

# %%
# Evaluate the new model loss and accuracy metrics
smote_model_2_loss, smote_model_2_accuracy = nn_2_smote.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {smote_model_2_loss}, Accuracy: {smote_model_2_accuracy * 100:.3f}%")
# Out:
# 13/13 - 0s - loss: 0.8840 - mse: 0.8840 - 215ms/epoch - 17ms/step
# Loss: 0.8840392231941223, Accuracy: 88.404%

# %%
# Set and save the model's file path - allowing for training run instances
path = f"saved_models/student_loans_2_smote.h5"
file_path = Path(path)
file_paths.append(path.split('/')[1:2][0])

# Export your model to an HDF5 file
nn_2_smote.save(file_path)

# %% [markdown]
# ### Step 4: Save and export your model to an HDF5 file, and name the file `student_loans.h5`.

# %%
# Each model saved above. Filenames stored as:
file_paths
# Out:
# ['student_loans.h5',
#  'student_loans_smote.h5',
#  'student_loans_2.h5',
#  'student_loans_2_smote.h5']

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the (best) model's file path
file_path = Path(f"saved_models/{file_paths[1]}")           # this will load new version of standard Sequential structure fit with SMOTE and 100 epochs
# file_path = Path(f"saved_models/student_loans_smote.h5")    # this file was uploaded to canvas, please add to Colab before funning this line of code
# Load the model to a new object
nn2_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data.

# %%
# Make predictions on the testing data for the loaded model (lm)
lm_y_pred = nn2_imported.predict(X_test_scaled).round().astype("int32").ravel()
print(lm_y_pred[:5])
lm_loss, lm_accuracy = nn2_imported.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {lm_loss}, Accuracy: {lm_accuracy * 100:.3f}%")
# Out:
# 13/13 [==============================] - 0s 6ms/step
# [6 5 6 5 7]
# 13/13 - 1s - loss: 0.9130 - mse: 0.9130 - 658ms/epoch - 51ms/step
# Loss: 0.9129549264907837, Accuracy: 91.295%

# %% [markdown]
# ### Step 3: Create a DataFrame to compare the predictions with the actual values.

# %%
# Create a DataFrame to compare the predictions with the actual values
results = pd.DataFrame({'prediction': lm_y_pred, 'actual': y_test})

# %% [markdown]
# ### Step 4: Display a sample of the DataFrame you created in step 3.

# %%
# Display sample data
results.sample(10)
# Out:
#      prediction  actual
# 230           4       6
# 143           4       5
# 161           7       6
# 307           7       5
# 94            7       5
# 301           5       6
# 244           6       6
# 386           5       5
# 225           5       5
# 5             7       6

# %%
# Accuracy Score Comparisons
print(f'   - -                     Random Forest Regressor model           accuracy: {rf_accuracy * 100:.3f}%')
print(f'   - -                     XG Boost model                          accuracy: {xg_srch_acc * 100:.3f}%')
print(f"({file_paths[0]})         Sequential model                        accuracy: {seq_model_accuracy * 100:.3f}%")
print(f"({file_paths[1]})   Sequential SMOTE sampled model          accuracy: {smote_model_accuracy * 100:.3f}%")
print(f"({file_paths[2]})       Expanded sequential model               accuracy: {seq_model_2_accuracy * 100:.3f}%")
print(f"({file_paths[3]}) Expanded sequential SMOTE sampled model accuracy: {smote_model_2_accuracy * 100:.3f}%")

# Compare distinct value counts for the original target and predicted target data
print('\nTarget Value Comparisons')
print(f'Original test value counts:\n{pd.DataFrame(y_test).value_counts()}')
print(f'Loaded Predictions (Expanded SMOTE) value counts:\n{pd.DataFrame(lm_y_pred).value_counts()}')
# Out:
#    - -                     Random Forest Regressor model           accuracy: 62.250%
#    - -                     XG Boost model                          accuracy: 68.750%
# (student_loans.h5)         Sequential model                        accuracy: 80.794%
# (student_loans_smote.h5)   Sequential SMOTE sampled model          accuracy: 91.295%
# (student_loans_2.h5)       Expanded sequential model               accuracy: 42.234%
# (student_loans_2_smote.h5) Expanded sequential SMOTE sampled model accuracy: 88.404%
#
# Target Value Comparisons
# Original test value counts:
# 5    171
# 6    167
# 7     42
# 4     16
# 8      3
# 3      1
# dtype: int64
# Loaded Predictions (Expanded SMOTE) value counts:
# 5    147
# 6    120
# 7     74
# 4     32
# 8     21
# 3      4
# 9      2
# dtype: int64

# %% [markdown]
# ##Evaluation
# ###Approach
# * Observed imbalance of results data. Given limited data, focussed on oversampling to increase lower value sets. Experimented with both SMOTE and SMOTEENN. The former yielded better results when applied to the Sequential model.
# * Attempted to establish a baseline accuracy with RandomForest and XGBoost
#   * Used Hyperparameter tuning to improve chance of best baseline - multiple attempts, including with SMOTE data
#   * Results were consistently in the low 60% range
#   * GridSearch was favoured over Random due to consistency of best result
# * Best accuracy achieved during model fitting was 0.91507667 with specified Sequential model structure (with 2 hidden layers) and scaled data - however this was lost through further experimental model training and I was unable to re-achieve it...lesson learnt - I should have saved it before moving on (save steps added)
# * NEXT best accuracy of 0.91295 was achieved with SMOTE sampled training data against the specified Sequential model structure with 100 epochs however the predictions included two target values (9) outside of the original range.
#
# Best result achieved in 4th training run ("saved_models/3/"). Given accuracy results varied significantly during notebook and training re-runs, would suggest sourcing more data overall (including a higher original proportion of lower credit rankings) to achieve higher accuracy with less risk of over-fitting.
#
# Final recommended model (based on the data provided and prepared and on multiple training runs) would be 'student_loans_smote.h5' however based on distributions of predictions, there may be some over-fitting.
